# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras import layers
from keras.utils import to_categorical

# %%
import numpy as np
import os

rootdir = 'C:\Rishi\Python\\ai\\Attractiveness-AI\CFD Version 3.0\Images\CFD_supersmall'
x_train_original = []
x_test_original = []
y_test_original = []
y_train_original = []

AF, AM, BF, BM, LF, LM, WF, WM = (0,0,0,0,0,0,0,0)
traincount = -1
testcount = -1

testopen = open("C:\Rishi\Python\\ai\Attractiveness-AI\y_train.txt", "r")
testread = testopen.read()
testlines = testread.splitlines()

trainopen = open("C:\Rishi\Python\\ai\Attractiveness-AI\y_test.txt", "r")
trainread = trainopen.read()
trainlines = trainread.splitlines()

## NEED TO REVISIT DATA. TRAIN AND TEST SETS SHOULD HAVE EQUAL NUMBER OF EACH RACE

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        if 'N' in os.path.join(subdir, file):
            if 'AF' in os.path.join(subdir, file):
                AF = AF + 1
                if AF < 41:
                    x_train_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("AF Train Done:" + str(AF))
                    traincount = traincount + 1
                    y = round(float(trainlines[traincount]))
                    y_train_original.append(y)
                else:
                    x_test_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("AF Test Done:" + str(AF))
                    testcount = testcount + 1
                    print(testcount)
                    y = round(float(testlines[testcount]))
                    y_test_original.append(y)
            elif 'AM' in os.path.join(subdir, file):
                AM = AM + 1
                if AM < 41:
                    x_train_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("AM Train Done:" + str(AM))
                    traincount = traincount + 1
                    y = round(float(trainlines[traincount]))
                    y_train_original.append(y)
                else:
                    x_test_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("AM Test Done:" + str(AM))
                    testcount = testcount + 1
                    print(testcount)
                    y = round(float(testlines[testcount]))
                    y_test_original.append(y)
            elif 'BF' in os.path.join(subdir, file):
                BF = BF + 1
                if BF < 71:
                    x_train_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("BF Train Done:" + str(BF))
                    traincount = traincount + 1
                    y = round(float(trainlines[traincount]))
                    y_train_original.append(y)
                else:
                    x_test_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("BF Test Done:" + str(BF))
                    testcount = testcount + 1
                    print(testcount)
                    y = round(float(testlines[testcount]))
                    y_test_original.append(y)
            elif 'BM' in os.path.join(subdir, file):
                BM = BM + 1
                if BM < 71:
                    x_train_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("BM Train Done:" + str(BM))
                    traincount = traincount + 1
                    y = round(float(trainlines[traincount]))
                    y_train_original.append(y)
                else:
                    x_test_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("BM Test Done:" + str(BM))
                    testcount = testcount + 1
                    print(testcount)
                    y = round(float(testlines[testcount]))
                    y_test_original.append(y)
            elif 'LF' in os.path.join(subdir, file):
                LF = LF + 1
                if LF < 41:
                    x_train_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("LF Train Done:" + str(LF))
                    traincount = traincount + 1
                    y = round(float(trainlines[traincount]))
                    y_train_original.append(y)
                else:
                    x_test_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("LF Test Done:" + str(LF))
                    testcount = testcount + 1
                    print(testcount)
                    y = round(float(testlines[testcount]))
                    y_test_original.append(y)
            elif 'LM' in os.path.join(subdir, file):
                LM = LM + 1
                if LM < 41:
                    x_train_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("LM Train Done:" + str(LM))
                    traincount = traincount + 1
                    y = round(float(trainlines[traincount]))
                    y_train_original.append(y)
                else:
                    x_test_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("LM Test Done:" + str(LM))
                    testcount = testcount + 1
                    print(testcount)
                    y = round(float(testlines[testcount]))
                    y_test_original.append(y)
            elif 'WF' in os.path.join(subdir, file):
                WF = WF + 1
                if WF < 71:
                    x_train_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("WF Train Done:" + str(WF))
                    traincount = traincount + 1
                    y = round(float(trainlines[traincount]))
                    y_train_original.append(y)
                else:
                    x_test_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("WF Test Done:" + str(WF))
                    testcount = testcount + 1
                    print(testcount)
                    y = round(float(testlines[testcount]))
                    y_test_original.append(y)
            elif 'WM' in os.path.join(subdir, file):
                WM = WM + 1
                if WM < 71:
                    x_train_original.append(mpimg.imread(os.path.join(subdir, file)))
                    print("WM Train Done:" + str(WM))
                    traincount = traincount + 1
                    y = round(float(trainlines[traincount]))
                    y_train_original.append(y)
                else:
                    x_test_original.append(mpimg.imread(os.path.join(subdir, file)))            
                    print("WM Test Done:" + str(WM))
                    testcount = testcount + 1
                    print(testcount)
                    y = round(float(testlines[testcount]))
                    y_test_original.append(y)
                
x_train = np.array(x_train_original)
x_test = np.array(x_test_original)

y_test = np.array([y_test_original]).T
y_train = np.array([y_train_original]).T
print(str(y_train.shape) + " " + str(y_test.shape))
# Out:
# AF Train Done:1
# AF Train Done:2
# AF Train Done:3
# AF Train Done:4
# AF Train Done:5
# AF Train Done:6
# AF Train Done:7
# AF Train Done:8
# AF Train Done:9
# AF Train Done:10
# AF Train Done:11
# AF Train Done:12
# AF Train Done:13
# AF Train Done:14
# AF Train Done:15
# AF Train Done:16
# AF Train Done:17
# AF Train Done:18
# AF Train Done:19
# AF Train Done:20
# AF Train Done:21
# AF Train Done:22
# AF Train Done:23
# AF Train Done:24
# AF Train Done:25
# AF Train Done:26
# AF Train Done:27
# AF Train Done:28
# AF Train Done:29
# AF Train Done:30
# AF Train Done:31
# AF Train Done:32
# AF Train Done:33
# AF Train Done:34
# AF Train Done:35
# AF Train Done:36
# AF Train Done:37
# AF Train Done:38
# AF Train Done:39
# AF Train Done:40
# AF Test Done:41
# 0
# AF Test Done:42
# 1
# AF Test Done:43
# 2
# AF Test Done:44
# 3
# AF Test Done:45
# 4
# AF Test Done:46
# 5
# AF Test Done:47
# 6
# AF Test Done:48
# 7
# AF Test Done:49
# 8
# AF Test Done:50
# 9
# AF Test Done:51
# 10
# AF Test Done:52
# 11
# AF Test Done:53
# 12
# AF Test Done:54
# 13
# AF Test Done:55
# 14
# AF Test Done:56
# 15
# AF Test Done:57
# 16
# AM Train Done:1
# AM Train Done:2
# AM Train Done:3
# AM Train Done:4
# AM Train Done:5
# AM Train Done:6
# AM Train Done:7
# AM Train Done:8
# AM Train Done:9
# AM Train Done:10
# AM Train Done:11
# AM Train Done:12
# AM Train Done:13
# AM Train Done:14
# AM Train Done:15
# AM Train Done:16
# AM Train Done:17
# AM Train Done:18
# AM Train Done:19
# AM Train Done:20
# AM Train Done:21
# AM Train Done:22
# AM Train Done:23
# AM Train Done:24
# AM Train Done:25
# AM Train Done:26
# AM Train Done:27
# AM Train Done:28
# AM Train Done:29
# AM Train Done:30
# AM Train Done:31
# AM Train Done:32
# AM Train Done:33
# AM Train Done:34
# AM Train Done:35
# AM Train Done:36
# AM Train Done:37
# AM Train Done:38
# AM Train Done:39
# AM Train Done:40
# AM Test Done:41
# 17
# AM Test Done:42
# 18
# AM Test Done:43
# 19
# AM Test Done:44
# 20
# AM Test Done:45
# 21
# AM Test Done:46
# 22
# AM Test Done:47
# 23
# AM Test Done:48
# 24
# AM Test Done:49
# 25
# AM Test Done:50
# 26
# AM Test Done:51
# 27
# AM Test Done:52
# 28
# BF Train Done:1
# BF Train Done:2
# BF Train Done:3
# BF Train Done:4
# BF Train Done:5
# BF Train Done:6
# BF Train Done:7
# BF Train Done:8
# BF Train Done:9
# BF Train Done:10
# BF Train Done:11
# BF Train Done:12
# BF Train Done:13
# BF Train Done:14
# BF Train Done:15
# BF Train Done:16
# BF Train Done:17
# BF Train Done:18
# BF Train Done:19
# BF Train Done:20
# BF Train Done:21
# BF Train Done:22
# BF Train Done:23
# BF Train Done:24
# BF Train Done:25
# BF Train Done:26
# BF Train Done:27
# BF Train Done:28
# BF Train Done:29
# BF Train Done:30
# BF Train Done:31
# BF Train Done:32
# BF Train Done:33
# BF Train Done:34
# BF Train Done:35
# BF Train Done:36
# BF Train Done:37
# BF Train Done:38
# BF Train Done:39
# BF Train Done:40
# BF Train Done:41
# BF Train Done:42
# BF Train Done:43
# BF Train Done:44
# BF Train Done:45
# BF Train Done:46
# BF Train Done:47
# BF Train Done:48
# BF Train Done:49
# BF Train Done:50
# BF Train Done:51
# BF Train Done:52
# BF Train Done:53
# BF Train Done:54
# BF Train Done:55
# BF Train Done:56
# BF Train Done:57
# BF Train Done:58
# BF Train Done:59
# BF Train Done:60
# BF Train Done:61
# BF Train Done:62
# BF Train Done:63
# BF Train Done:64
# BF Train Done:65
# BF Train Done:66
# BF Train Done:67
# BF Train Done:68
# BF Train Done:69
# BF Train Done:70
# BF Test Done:71
# 29
# BF Test Done:72
# 30
# BF Test Done:73
# 31
# BF Test Done:74
# 32
# BF Test Done:75
# 33
# BF Test Done:76
# 34
# BF Test Done:77
# 35
# BF Test Done:78
# 36
# BF Test Done:79
# 37
# BF Test Done:80
# 38
# BF Test Done:81
# 39
# BF Test Done:82
# 40
# BF Test Done:83
# 41
# BF Test Done:84
# 42
# BF Test Done:85
# 43
# BF Test Done:86
# 44
# BF Test Done:87
# 45
# BF Test Done:88
# 46
# BF Test Done:89
# 47
# BF Test Done:90
# 48
# BF Test Done:91
# 49
# BF Test Done:92
# 50
# BF Test Done:93
# 51
# BF Test Done:94
# 52
# BF Test Done:95
# 53
# BF Test Done:96
# 54
# BF Test Done:97
# 55
# BF Test Done:98
# 56
# BF Test Done:99
# 57
# BF Test Done:100
# 58
# BF Test Done:101
# 59
# BF Test Done:102
# 60
# BF Test Done:103
# 61
# BF Test Done:104
# 62
# BM Train Done:1
# BM Train Done:2
# BM Train Done:3
# BM Train Done:4
# BM Train Done:5
# BM Train Done:6
# BM Train Done:7
# BM Train Done:8
# BM Train Done:9
# BM Train Done:10
# BM Train Done:11
# BM Train Done:12
# BM Train Done:13
# BM Train Done:14
# BM Train Done:15
# BM Train Done:16
# BM Train Done:17
# BM Train Done:18
# BM Train Done:19
# BM Train Done:20
# BM Train Done:21
# BM Train Done:22
# BM Train Done:23
# BM Train Done:24
# BM Train Done:25
# BM Train Done:26
# BM Train Done:27
# BM Train Done:28
# BM Train Done:29
# BM Train Done:30
# BM Train Done:31
# BM Train Done:32
# BM Train Done:33
# BM Train Done:34
# BM Train Done:35
# BM Train Done:36
# BM Train Done:37
# BM Train Done:38
# BM Train Done:39
# BM Train Done:40
# BM Train Done:41
# BM Train Done:42
# BM Train Done:43
# BM Train Done:44
# BM Train Done:45
# BM Train Done:46
# BM Train Done:47
# BM Train Done:48
# BM Train Done:49
# BM Train Done:50
# BM Train Done:51
# BM Train Done:52
# BM Train Done:53
# BM Train Done:54
# BM Train Done:55
# BM Train Done:56
# BM Train Done:57
# BM Train Done:58
# BM Train Done:59
# BM Train Done:60
# BM Train Done:61
# BM Train Done:62
# BM Train Done:63
# BM Train Done:64
# BM Train Done:65
# BM Train Done:66
# BM Train Done:67
# BM Train Done:68
# BM Train Done:69
# BM Train Done:70
# BM Test Done:71
# 63
# BM Test Done:72
# 64
# BM Test Done:73
# 65
# BM Test Done:74
# 66
# BM Test Done:75
# 67
# BM Test Done:76
# 68
# BM Test Done:77
# 69
# BM Test Done:78
# 70
# BM Test Done:79
# 71
# BM Test Done:80
# 72
# BM Test Done:81
# 73
# BM Test Done:82
# 74
# BM Test Done:83
# 75
# BM Test Done:84
# 76
# BM Test Done:85
# 77
# BM Test Done:86
# 78
# BM Test Done:87
# 79
# BM Test Done:88
# 80
# BM Test Done:89
# 81
# BM Test Done:90
# 82
# BM Test Done:91
# 83
# BM Test Done:92
# 84
# BM Test Done:93
# 85
# LF Train Done:1
# LF Train Done:2
# LF Train Done:3
# LF Train Done:4
# LF Train Done:5
# LF Train Done:6
# LF Train Done:7
# LF Train Done:8
# LF Train Done:9
# LF Train Done:10
# LF Train Done:11
# LF Train Done:12
# LF Train Done:13
# LF Train Done:14
# LF Train Done:15
# LF Train Done:16
# LF Train Done:17
# LF Train Done:18
# LF Train Done:19
# LF Train Done:20
# LF Train Done:21
# LF Train Done:22
# LF Train Done:23
# LF Train Done:24
# LF Train Done:25
# LF Train Done:26
# LF Train Done:27
# LF Train Done:28
# LF Train Done:29
# LF Train Done:30
# LF Train Done:31
# LF Train Done:32
# LF Train Done:33
# LF Train Done:34
# LF Train Done:35
# LF Train Done:36
# LF Train Done:37
# LF Train Done:38
# LF Train Done:39
# LF Train Done:40
# LF Test Done:41
# 86
# LF Test Done:42
# 87
# LF Test Done:43
# 88
# LF Test Done:44
# 89
# LF Test Done:45
# 90
# LF Test Done:46
# 91
# LF Test Done:47
# 92
# LF Test Done:48
# 93
# LF Test Done:49
# 94
# LF Test Done:50
# 95
# LF Test Done:51
# 96
# LF Test Done:52
# 97
# LF Test Done:53
# 98
# LF Test Done:54
# 99
# LF Test Done:55
# 100
# LF Test Done:56
# 101
# LM Train Done:1
# LM Train Done:2
# LM Train Done:3
# LM Train Done:4
# LM Train Done:5
# LM Train Done:6
# LM Train Done:7
# LM Train Done:8
# LM Train Done:9
# LM Train Done:10
# LM Train Done:11
# LM Train Done:12
# LM Train Done:13
# LM Train Done:14
# LM Train Done:15
# LM Train Done:16
# LM Train Done:17
# LM Train Done:18
# LM Train Done:19
# LM Train Done:20
# LM Train Done:21
# LM Train Done:22
# LM Train Done:23
# LM Train Done:24
# LM Train Done:25
# LM Train Done:26
# LM Train Done:27
# LM Train Done:28
# LM Train Done:29
# LM Train Done:30
# LM Train Done:31
# LM Train Done:32
# LM Train Done:33
# LM Train Done:34
# LM Train Done:35
# LM Train Done:36
# LM Train Done:37
# LM Train Done:38
# LM Train Done:39
# LM Train Done:40
# LM Test Done:41
# 102
# LM Test Done:42
# 103
# LM Test Done:43
# 104
# LM Test Done:44
# 105
# LM Test Done:45
# 106
# LM Test Done:46
# 107
# LM Test Done:47
# 108
# LM Test Done:48
# 109
# LM Test Done:49
# 110
# LM Test Done:50
# 111
# LM Test Done:51
# 112
# LM Test Done:52
# 113
# WF Train Done:1
# WF Train Done:2
# WF Train Done:3
# WF Train Done:4
# WF Train Done:5
# WF Train Done:6
# WF Train Done:7
# WF Train Done:8
# WF Train Done:9
# WF Train Done:10
# WF Train Done:11
# WF Train Done:12
# WF Train Done:13
# WF Train Done:14
# WF Train Done:15
# WF Train Done:16
# WF Train Done:17
# WF Train Done:18
# WF Train Done:19
# WF Train Done:20
# WF Train Done:21
# WF Train Done:22
# WF Train Done:23
# WF Train Done:24
# WF Train Done:25
# WF Train Done:26
# WF Train Done:27
# WF Train Done:28
# WF Train Done:29
# WF Train Done:30
# WF Train Done:31
# WF Train Done:32
# WF Train Done:33
# WF Train Done:34
# WF Train Done:35
# WF Train Done:36
# WF Train Done:37
# WF Train Done:38
# WF Train Done:39
# WF Train Done:40
# WF Train Done:41
# WF Train Done:42
# WF Train Done:43
# WF Train Done:44
# WF Train Done:45
# WF Train Done:46
# WF Train Done:47
# WF Train Done:48
# WF Train Done:49
# WF Train Done:50
# WF Train Done:51
# WF Train Done:52
# WF Train Done:53
# WF Train Done:54
# WF Train Done:55
# WF Train Done:56
# WF Train Done:57
# WF Train Done:58
# WF Train Done:59
# WF Train Done:60
# WF Train Done:61
# WF Train Done:62
# WF Train Done:63
# WF Train Done:64
# WF Train Done:65
# WF Train Done:66
# WF Train Done:67
# WF Train Done:68
# WF Train Done:69
# WF Train Done:70
# WF Test Done:71
# 114
# WF Test Done:72
# 115
# WF Test Done:73
# 116
# WF Test Done:74
# 117
# WF Test Done:75
# 118
# WF Test Done:76
# 119
# WF Test Done:77
# 120
# WF Test Done:78
# 121
# WF Test Done:79
# 122
# WF Test Done:80
# 123
# WF Test Done:81
# 124
# WF Test Done:82
# 125
# WF Test Done:83
# 126
# WF Test Done:84
# 127
# WF Test Done:85
# 128
# WF Test Done:86
# 129
# WF Test Done:87
# 130
# WF Test Done:88
# 131
# WF Test Done:89
# 132
# WF Test Done:90
# 133
# WM Train Done:1
# WM Train Done:2
# WM Train Done:3
# WM Train Done:4
# WM Train Done:5
# WM Train Done:6
# WM Train Done:7
# WM Train Done:8
# WM Train Done:9
# WM Train Done:10
# WM Train Done:11
# WM Train Done:12
# WM Train Done:13
# WM Train Done:14
# WM Train Done:15
# WM Train Done:16
# WM Train Done:17
# WM Train Done:18
# WM Train Done:19
# WM Train Done:20
# WM Train Done:21
# WM Train Done:22
# WM Train Done:23
# WM Train Done:24
# WM Train Done:25
# WM Train Done:26
# WM Train Done:27
# WM Train Done:28
# WM Train Done:29
# WM Train Done:30
# WM Train Done:31
# WM Train Done:32
# WM Train Done:33
# WM Train Done:34
# WM Train Done:35
# WM Train Done:36
# WM Train Done:37
# WM Train Done:38
# WM Train Done:39
# WM Train Done:40
# WM Train Done:41
# WM Train Done:42
# WM Train Done:43
# WM Train Done:44
# WM Train Done:45
# WM Train Done:46
# WM Train Done:47
# WM Train Done:48
# WM Train Done:49
# WM Train Done:50
# WM Train Done:51
# WM Train Done:52
# WM Train Done:53
# WM Train Done:54
# WM Train Done:55
# WM Train Done:56
# WM Train Done:57
# WM Train Done:58
# WM Train Done:59
# WM Train Done:60
# WM Train Done:61
# WM Train Done:62
# WM Train Done:63
# WM Train Done:64
# WM Train Done:65
# WM Train Done:66
# WM Train Done:67
# WM Train Done:68
# WM Train Done:69
# WM Train Done:70
# WM Test Done:71
# 134
# WM Test Done:72
# 135
# WM Test Done:73
# 136
# WM Test Done:74
# 137
# WM Test Done:75
# 138
# WM Test Done:76
# 139
# WM Test Done:77
# 140
# WM Test Done:78
# 141
# WM Test Done:79
# 142
# WM Test Done:80
# 143
# WM Test Done:81
# 144
# WM Test Done:82
# 145
# WM Test Done:83
# 146
# WM Test Done:84
# 147
# WM Test Done:85
# 148
# WM Test Done:86
# 149
# WM Test Done:87
# 150
# WM Test Done:88
# 151
# WM Test Done:89
# 152
# WM Test Done:90
# 153
# WM Test Done:91
# 154
# WM Test Done:92
# 155
# WM Test Done:93
# 156
# (440, 1) (157, 1)

# %%
model = Sequential()

model.add(Conv2D(64, (5, 5), activation='relu', input_shape=(64, 64, 3)))

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (5, 5), activation='relu'))

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(100, activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(50, activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(2, activation='relu'))

model.add(Dense(7, activation='softmax'))

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])
y_train_onehot = to_categorical(y_train, 7)
y_test_onehot = to_categorical(y_test, 7)
tf.config.run_functions_eagerly(True)

print(y_train_onehot[30])
print(y_train[30])
# Out:
# [0. 0. 0. 0. 0. 1. 0.]
# [5]

# %%
hist = model.fit(x_train, y_train_onehot,
                batch_size = 440,
                epochs = 5,
                validation_split = 0.1)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 2s 2s/step - loss: 19.4581 - accuracy: 0.0000e+00 - val_loss: 1.9451 - val_accuracy: 0.2727
# Epoch 2/5
# 1/1 [==============================] - 2s 2s/step - loss: 12.8160 - accuracy: 0.1641 - val_loss: 1.9440 - val_accuracy: 0.5455
# Epoch 3/5
# 1/1 [==============================] - 2s 2s/step - loss: 5.7141 - accuracy: 0.4545 - val_loss: 1.9430 - val_accuracy: 0.5455
# Epoch 4/5
# 1/1 [==============================] - 2s 2s/step - loss: 3.6651 - accuracy: 0.4798 - val_loss: 1.9419 - val_accuracy: 0.5455
# Epoch 5/5
# 1/1 [==============================] - 2s 2s/step - loss: 3.4349 - accuracy: 0.4672 - val_loss: 1.9409 - val_accuracy: 0.5455

# %%
model.evaluate(x_test, y_test_onehot)[1]
# Out:
# 5/5 [==============================] - 0s 46ms/step - loss: 1.9418 - accuracy: 0.3949
# 0.3949044644832611

# %%
img = mpimg.imread('test_img.jpg') # Your test image
imgplot = plt.imshow(img)
plt.show()

# %%
prediction = model.predict(np.array([img]))
prediction
# Out:
# 1/1 [==============================] - 0s 23ms/step
# array([[0.14218836, 0.14228038, 0.14354292, 0.14359818, 0.14357989,
#         0.1426196 , 0.14219071]], dtype=float32)

# %%
list_index = [0,1,2,3,4,5,6]
x = prediction
for i in range(7):
    for j in range(7):
        if x[0][list_index[i]] > x[0][list_index[j]]:
            temp = list_index[i]
            list_index[i] = list_index[j]
            list_index[j] = temp
print(list_index)
# Out:
# [3, 4, 2, 5, 1, 6, 0]
